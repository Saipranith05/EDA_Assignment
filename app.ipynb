# %%
import pandas as pd

# %%
df = pd.read_csv("students_performance.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0  Hours_Studied  Attendance Parental_Involvement  \
# 0           0             23          84                  Low
# 1           1             19          64                  Low
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Family_Income  \
# 0               73              Low             Yes  ...            Low
# 1               59              Low             Yes  ...         Medium
#
#   Teacher_Quality School_Type Peer_Influence Physical_Activity  \
# 0          Medium      Public       Positive                 3
# 1          Medium      Public       Negative                 4
#
#    Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender  \
# 0                     No              High School               Near    Male
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.drop(columns = ["Unnamed: 0"], inplace=True)

# %%
df.head(2)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(df["Teacher_Quality"])
# Out:
# <Axes: ylabel='Teacher_Quality'>

# %%
Teacher_Quality_mode = df["Teacher_Quality"].mode()[0]

# %%
df["Teacher_Quality"].value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
df["Teacher_Quality"].fillna(Teacher_Quality_mode, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_16288\2945149743.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Teacher_Quality"].fillna(Teacher_Quality_mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df["Parental_Education_Level"].value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
Parental_Education_Level_mode = df["Parental_Education_Level"].mode()[0]

# %%
df["Parental_Education_Level"].fillna(Parental_Education_Level_mode, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_16288\2059701743.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Parental_Education_Level"].fillna(Parental_Education_Level_mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level       0
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
sns.boxplot(df['Distance_from_Home'])
# Out:
# <Axes: ylabel='Distance_from_Home'>

# %%
Distance_from_Home_mode = df["Distance_from_Home"].mode()[0]

# %%
df["Distance_from_Home"].fillna(Distance_from_Home_mode, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_16288\136575233.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Distance_from_Home"].fillna(Distance_from_Home_mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
sns.boxplot(df["Exam_Score"]) # Hours_Studied,Tutoring_Sessions,Learning_Disabilities,Exam_Score
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
q1 = df.describe()["Hours_Studied"]["25%"]

# %%
q3 = df.describe()["Hours_Studied"]["75%"]

# %%
IQR = q3 - q1

# %%
int(IQR)
# Out:
# 8

# %%
lower_limit = q1 - 1.5 * IQR
upper_limit = q3 + 15 * IQR

# %%
df[(df["Hours_Studied"]>upper_limit) | (df["Hours_Studied"]<lower_limit)].count()
# Out:
# Hours_Studied                 21
# Attendance                    21
# Parental_Involvement          21
# Access_to_Resources           21
# Extracurricular_Activities    21
# Sleep_Hours                   21
# Previous_Scores               21
# Motivation_Level              21
# Internet_Access               21
# Tutoring_Sessions             21
# Family_Income                 21
# Teacher_Quality               21
# School_Type                   21
# Peer_Influence                21
# Physical_Activity             21
# Learning_Disabilities         21
# Parental_Education_Level      21
# Distance_from_Home            21
# Gender                        21
# Exam_Score                    21
# dtype: int64

# %%
df["Hours_Studied"].clip(lower_limit,upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_16288\1687344623.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Hours_Studied"].clip(lower_limit,upper_limit, inplace=True)

# %%
sns.boxplot(df["Hours_Studied"])
# Out:
# <Axes: ylabel='Hours_Studied'>

# %%
df[(df["Hours_Studied"]>upper_limit) | (df["Hours_Studied"]<lower_limit)]
# Out:
# Empty DataFrame
# Columns: [Hours_Studied, Attendance, Parental_Involvement, Access_to_Resources, Extracurricular_Activities, Sleep_Hours, Previous_Scores, Motivation_Level, Internet_Access, Tutoring_Sessions, Family_Income, Teacher_Quality, School_Type, Peer_Influence, Physical_Activity, Learning_Disabilities, Parental_Education_Level, Distance_from_Home, Gender, Exam_Score]
# Index: []

# %%
sns.boxplot(df["Tutoring_Sessions"])
# Out:
# <Axes: ylabel='Tutoring_Sessions'>

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.980324    79.977448      7.02906        75.070531
# std         5.976458    11.547475      1.46812        14.399784
# min         4.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
q1 = df.describe()["Tutoring_Sessions"]["25%"]

q3 = df.describe()["Tutoring_Sessions"]["75%"]

# %%
lower_limit = q1 - 1.5 * IQR
upper_limit = q3 + 1.5 * IQR

# %%
IQR = q3 - q1

# %%
int(IQR)
# Out:
# 1

# %%
df[(df["Tutoring_Sessions"]>upper_limit) | (df["Tutoring_Sessions"]<lower_limit)].count()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
sns.boxplot(df["Exam_Score"])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.980324    79.977448      7.02906        75.070531
# std         5.976458    11.547475      1.46812        14.399784
# min         4.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
q1 = df.describe()["Exam_Score"]["25%"]

# %%
q3 = df.describe()["Exam_Score"]["75%"]

# %%
IQR = q3 - q3

# %%
int(IQR)
# Out:
# 0

# %%
lower_limit = q1 - 1.5 * IQR

upper_limit = q3 + 1.5 * IQR

# %%
df[(df["Exam_Score"]>upper_limit) | (df["Exam_Score"]<lower_limit)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# 5                19          88               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6595             28          78               Medium                High
# 6597             16          91                 High              Medium
# 6598              9          87                  Low              Medium
# 6599             30          94               Medium                 Low
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df["Exam_Score"].clip(lower_limit,upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_16288\970302717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Exam_Score"].clip(lower_limit,upper_limit, inplace=True)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# ...

# %%
# ordianl == Parental_Involvement, Access_to_Resources, Motivation_Level, Family_Income, 
# Teacher_Quality, Parental_Education_Level, Distance_from_Home
# nominal == Extracurricular_Activities, Internet_Access, School_Type, Peer_Influence,
# Learning_Disabiliites, Gender

# %%
df["Extracurricular_Activities"].value_counts()
# Out:
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64

# %%
df["Internet_Access"].value_counts()
# Out:
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64

# %%
df["School_Type"].value_counts() # nominal
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# ...

# %%
df["Parental_Involvement"].value_counts()
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64

# %%
d1 = {"Low":0, "Medium":1, "High":2}
df["Parental_Involvement"] = df["Parental_Involvement"].map(d1)

# %%
d3 = {"Low":0, "Medium":1, "High":2}
df["Motivation_Level"] = df["Motivation_Level"].map(d3)

# %%
d4 = {"Low":0, "Medium":1, "High":2}
df["Family_Income"] = df["Family_Income"].map(d4)

# %%
d5 = {"Low":0, "Medium":1, "High":2}
df["Teacher_Quality"] = df["Teacher_Quality"].map(d5)

# %%
d2 = {"Low":0, "Medium":1, "High":2}
df["Access_to_Resources"] = df["Access_to_Resources"].map(d2)

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     0                    2
# 1             19          64                     0                    1
# 2             24          98                     1                    1
# 3             29          89                     0                    1
# 4             19          92                     1                    1
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                         No            7               73                 0
# 1                         No            8               59                 0
# 2                        Yes            7               91                 1
# 3                        Yes            8               98                 1
# 4                        Yes            6               65                 1
#
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns = ["Internet_Access", "School_Type", "Peer_Influence", "Learning_Disabilities", "Distance_from_Home", "Gender"], dtype='int64', drop_first=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     0                    2
# 1             19          64                     0                    1
# 2             24          98                     1                    1
# 3             29          89                     0                    1
# 4             19          92                     1                    1
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                         No            7               73                 0
# 1                         No            8               59                 0
# 2                        Yes            7               91                 1
# 3                        Yes            8               98                 1
# 4                        Yes            6               65                 1
#
#    Tutoring_Sessions  Family_Income  ...  Parental_Education_Level  \
# ...

# %%
#Normalization
df.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     0                    2
# 1             19          64                     0                    1
# 2             24          98                     1                    1
# 3             29          89                     0                    1
# 4             19          92                     1                    1
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                         No            7               73                 0
# 1                         No            8               59                 0
# 2                        Yes            7               91                 1
# 3                        Yes            8               98                 1
# 4                        Yes            6               65                 1
#
#    Tutoring_Sessions  Family_Income  ...  Parental_Education_Level  \
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
df_normal = df.copy

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     0                    2
# 1             19          64                     0                    1
# 2             24          98                     1                    1
# 3             29          89                     0                    1
# 4             19          92                     1                    1
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                         No            7               73                 0
# 1                         No            8               59                 0
# 2                        Yes            7               91                 1
# 3                        Yes            8               98                 1
# 4                        Yes            6               65                 1
#
#    Tutoring_Sessions  Family_Income  ...  Parental_Education_Level  \
# ...

# %%
type(df_normal)
# Out:
# method

# %%
! pip install scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()

# %%
pranithyadav = mm.fit_transform(df_normal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 pranithyadav = mm.fit_transform(df_normal)
#
# File c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
df_standard = df.copy()

# %%
df_numeric = df_standard.select_dtypes(include=[float, int])

# %%
import numpy as np
df_numeric = df_numeric.replace([np.inf, -np.inf], np.nan)
df_numeric = df_numeric.dropna()

# %%
import pandas as pd
df_scaled = pd.DataFrame(df_scaled, columns=df_numeric.columns)

# %%
df_scaled = ss.fit_transform(df_numeric)

# %%
print(df_numeric.shape)
# Out:
# (6607, 21)

# %%
df_scaled
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0          0.505300    0.348375             -1.562146             1.288574
# 1         -0.164043   -1.383736             -1.562146            -0.143488
# 2          0.672636    1.560853             -0.124267            -0.143488
# 3          1.509315    0.781403             -1.562146            -0.143488
# 4         -0.164043    1.041220             -0.124267            -0.143488
# ...             ...         ...                   ...                  ...
# 6602       0.839972   -0.950708              1.313613            -0.143488
# 6603       0.505300   -0.344469              1.313613            -0.143488
# 6604       0.003293    0.868009             -0.124267            -1.575549
# 6605      -1.670066    0.521587              1.313613             1.288574
# 6606      -0.833387   -1.123919             -0.124267            -1.575549
#
# ...

# %%
df_nor = df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
nor = MinMaxScaler()

# %%
df_nor_numeric = df_nor.select_dtypes(include=[float, int])

# %%
df_nor_numeric = df_nor_numeric.replace([np.inf, -np.inf], np.nan).dropna()

# %%
print(type(df_nor_numeric))  # Should return <class 'pandas.core.frame.DataFrame'>
print(df_nor_numeric.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (6607, 21)

# %%
nor = MinMaxScaler()

# %%
pra = nor.fit_transform(df_nor_numeric)

# %%
pra_df = pd.DataFrame(pra, columns=df_nor_numeric.columns)

# %%
pra_df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             0.475       0.600                   0.0                  1.0
# 1             0.375       0.100                   0.0                  0.5
# 2             0.500       0.950                   0.5                  0.5
# 3             0.625       0.725                   0.0                  0.5
# 4             0.375       0.800                   0.5                  0.5
# ...             ...         ...                   ...                  ...
# 6602          0.525       0.225                   1.0                  0.5
# 6603          0.475       0.400                   1.0                  0.5
# 6604          0.400       0.750                   0.5                  0.0
# 6605          0.150       0.650                   1.0                  1.0
# 6606          0.275       0.175                   0.5                  0.0
#
# ...
